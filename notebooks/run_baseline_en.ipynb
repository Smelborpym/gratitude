# %%
# %load_ext autoreload
# %autoreload 2


import pandas as pd
import spacy
nlp = spacy.load("en_core_web_lg")

from os import getcwd, listdir
from os.path import join, dirname, isfile

PATH_REPO = dirname(getcwd())
PATH_UTILS = join(PATH_REPO, 'utils')
PATH_DATA = join(PATH_REPO, 'data')
PATH_CONFIG = join(PATH_REPO, 'config')
PATH_RESULTS = join(PATH_REPO, 'results')

import sys
sys.path.append(PATH_UTILS)


from baseline import load_t_matcher, run_baseline
from metrics import pipeline_report

from sklearn.metrics import precision_recall_fscore_support as score

import numpy as np

pd.set_option('max_colwidth', None)

# %%
data = pd.read_csv(join(PATH_DATA, "test_set.csv"), names = ['text', 'label'], engine="python",skiprows=1)
# data['label'] = np.where(data['label']=="Gratitude", 1, 0)
data['text'] = data['text'].astype(str)
texts = data['text'].values.tolist()
data
# Out:
#                                                                                                                                                                                                                                                                                             text  \
# 0                             Another great IPC meeting. A huge thank you to our amazing Mo and Sarah USER USER who have provided consistent and compassionate infectioncontrol leadership throughout COVID19 Pandemic. 'IPC is everyone's business' is your legacy We all will miss you â¤ï¸
# 1                                                                                                         Weâ€™re all set for this evenings USER first up weâ€™re hearing from keynote speaker Mel Smith CEO of USER talking about the huge rise in online food shopping thanks to COVID19 CFL21
# 2      The vaccine programme, the largest in NHS history, is currently moving through Scots who are between 70 and 79 years old, with progress speeding up thanks to the launch of mass vaccination centres such as those at the P&amp;J Live in Aberdeen and Edinburgh International Conference
# 3                                              Had a text offering me the vaccination. Booked in for Friday at Clarendon Recreation Centre. USER NHS workers and all involved are doing an amazing job of getting the vaccine out in Salford. Thank you for your efforts. SpiritOfSalfordâ¤ï¸
# 4                               Many thanks to USER for highlighting the impact of smell and taste disorders with this powerful video. I founded USER with USER in 2012 after losing my sense of smell through head injury. Weâ€™re here to provide support &amp; information to anyone in need.
# ...                                                                                                                                                                                                                                                                                          ...
# 16764  USER There are models of edtech integration that build up to learning activities that can only occur online. I suggest that several skirt the boundary of web 3. Sadly, often the most enthusiastic teacher's hands are tied by school policy and exam deadlines, and never get that far.
# 16765                                                                                              Yâ€™all have forced me to think about politics and by â€œthink about politicsâ€ I mean hoping, praying and waiting for the day weâ€™re discussing parties that arenâ€™t UN* and PN* ðŸ¥´ðŸ¥´
# 16766                              From the time a Speaker can say that there is to be no debate on the issueâ€¦just the casting of a voteâ€¦I already wrote this fiasco as utter rubbishâ€¦and Iâ€™m genuinely not surprised by what took place today. Love that for us as tax-paying citizens.
# 16767                                                                                                                                                                                                                 This town would have no more residents by the time Love &amp; Joe done yes
# 16768                                                                                                                                                                                             USER Underserved communities is the new bait and switch word when addressing black communities
#
#        label
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 16764    NaN
# 16765    NaN
# 16766    NaN
# 16767    NaN
# 16768    NaN
#
# [16769 rows x 2 columns]

# %%
docs = list(nlp.pipe(texts))

# %%
t_mat = load_t_matcher(PATH_CONFIG, 't_patterns.json', nlp)
# p_mat = load_p_matcher(PATH_CONFIG, 'ph_patterns.json', nlp)

# %%
predictions = []
patterns = []
sequences = []

for doc in docs:
  appre, pat, seq = run_baseline(nlp, doc, t_mat)
  predictions.append(appre)
  patterns.append(pat)
  sequences.append(seq)


data['prediction'] = np.where(predictions, 1, 0)
data['patterns'] = patterns
data['matching sequences'] = sequences

# %%
data.head()
# Out:
#                                                                                                                                                                                                                                                                                         text  \
# 0                         Another great IPC meeting. A huge thank you to our amazing Mo and Sarah USER USER who have provided consistent and compassionate infectioncontrol leadership throughout COVID19 Pandemic. 'IPC is everyone's business' is your legacy We all will miss you â¤ï¸
# 1                                                                                                     Weâ€™re all set for this evenings USER first up weâ€™re hearing from keynote speaker Mel Smith CEO of USER talking about the huge rise in online food shopping thanks to COVID19 CFL21
# 2  The vaccine programme, the largest in NHS history, is currently moving through Scots who are between 70 and 79 years old, with progress speeding up thanks to the launch of mass vaccination centres such as those at the P&amp;J Live in Aberdeen and Edinburgh International Conference
# 3                                          Had a text offering me the vaccination. Booked in for Friday at Clarendon Recreation Centre. USER NHS workers and all involved are doing an amazing job of getting the vaccine out in Salford. Thank you for your efforts. SpiritOfSalfordâ¤ï¸
# 4                           Many thanks to USER for highlighting the impact of smell and taste disorders with this powerful video. I founded USER with USER in 2012 after losing my sense of smell through head injury. Weâ€™re here to provide support &amp; information to anyone in need.
#
#    label  prediction                                        patterns  \
# 0    NaN           1                            [Explicit Gratitude]
# 1    NaN           1                            [Explicit Gratitude]
# 2    NaN           1                            [Explicit Gratitude]
# 3    NaN           1  [Expressing Appreciation3, Explicit Gratitude]
# 4    NaN           1                            [Explicit Gratitude]
#
#          matching sequences
# 0               [thank you]
# 1               [thanks to]
# 2               [thanks to]
# 3  [amazing job, Thank you]
# 4               [thanks to]

# %%
precision, recall, fscore, support = score(data['label'] ,data['prediction'], average='macro')
print("Precision:\t", precision, "\n", "Recall:\t", recall, "\n", "F1:\t", fscore)
# Out:
# Precision:	 0.9177561568865917
#  Recall:	 0.9173513075676927
#  F1:	 0.9175503145677995

# %% [markdown]
# ## Check the false positives:

# %%
print(len(data[(data['label']==0) & (data['prediction']==1)]))
data[(data['label']==0) & (data['prediction']==1)][0:68]
# Out:
# 21
#                                                                                                                                                                                                                                                                                               text  \
# 24                                                                                                                                                    USER I hear you're the best, I fly 2x a week &amp; USER has let me down big. Get me to DC by 2:30pm tom &amp; I'll give you my money instead
# 30                                                                                                                                            USER You’re very kind, but it’s 9:32pm&amp;I need to relax. I’ll be happy to connect tomorrow through DM. Can’t say your CS isn’t prompt! Thank you.
# 39                                                                                                                             USER That's very kind of you, but this was a while back. Amazon already fixed the issue, even though it wasn't their fault the delivery went to the wrong house. :)
# 45                                                                                        Shout out to USER for lying to me about my plan, when trying to get it fixed telling me there is nothing to do about it and to this day having the worst customer service out there. You're the best. :)
# 68                                                                                                                                                 USER You misunderstand, I'm just asking if its possible, I haven't tried it yet (still a couple of days on my trial),many thanks for helping :)
# 273                                                                                                                                                     USER i love iOS 11. it’s so fun having a phone that freezes, restarts, and messes up every ten minutes. thank you for being incompetent :)
# 277                                                                                                             USER Dear Hulu: Please get rid of the new interface. The new interface is TRASH! Thank you for your prompt attention to this matter. Long Time Customer hulu newinterface epicfail
# 279                                                                                                          USER Though I have amazon India account, for next few months, i'll be in South Korea. Will be great if there is a way amazon india can deliver it to here ;) Thank you for the help 😀
# 311                                                                                                                                                         USER hello, is there a possibility to request my oyster travel history older than three months? I need data from July. Thanks a lot :)
# 313                                                                                                                                                                                              USER I was suppose to land in San Fran at 8:30. I didn’t land u til after midnight. Thanks a lot.
# 314                                                                                                                                                                                           USER Good day! please help to check out when this code was used, Code: 3MC3-L6N6-CL6F,thanks a lot .
# 319                                                                                                                                                       &amp; now just sitting on runway at SF....It’s past midnight &amp; at this rate I won’t be home till 1:30-2am. Thanks USER thanks a lot😐
# 323                                                                                                                                                                     USER Just going to wait on one final order that I’ve got arriving in a couple days, then I’ll message you. Thanks a lot :)
# 335  USER I really appreciate your response. However, I already submitted a bug back when 9 was first released: 34620605. No work seems to have been done towards fixing the regression I identified in 9.2 b2. Any acknowledgement or feedback is appreciated, but I haven’t received any. contd:
# 342                                                                                                                                                                               USER Thank you. Appreciate if you guys can have your website to include ILO in the list for easier reference. :)
# 344                                              USER Thank you, I’ll be honest, my patience is starting to wear a bit thin :). Had to take time off work yesterday to sort it, and I’m at Work again now. It’s not just inconvenience now it’s starting to cost me money. I appreciate your help.
# 345                                                                           USER Official boarding time was shifted to 7:39am, yet it's 7:47am, and no announcement has been made by the agent for my gate. This is honestly ridiculous. I appreciate prompt responses, but not empty apologies.
# 354                                                                                                                                                                                                          USER USER Thank you Emily I hope so. Flying stresses me the hell out and now this 😭😭😭
# 475                                                                                                                                                           USER Why do u no longer sell Alcafe Colombian roast n ground coffee? So disappointed as it took ages to find a coffee I really like!
# 507                                                                                                                                                                                                          Two whisky sours and hot food for low price of nothing :3 Thanks USER SapphireReserve
# 612                                                                    USER We understand your frustration. We're so sorry to hear that your experience wasn't great. Thanks for taking the time to share your feedback with us. We'll pass this along to our inflight leadership team for review.
#
#      label  prediction                                     patterns  \
# 24       0           1                                           []
# 30       0           1                         [Explicit Gratitude]
# 39       0           1                  [Emphasizing Apperciation2]
# 45       0           1                                           []
# 68       0           1                         [Explicit Gratitude]
# 273      0           1                         [Explicit Gratitude]
# 277      0           1                         [Explicit Gratitude]
# 279      0           1                         [Explicit Gratitude]
# 311      0           1                         [Explicit Gratitude]
# 313      0           1                         [Explicit Gratitude]
# 314      0           1                         [Explicit Gratitude]
# 319      0           1     [Explicit Gratitude, Explicit Gratitude]
# 323      0           1                         [Explicit Gratitude]
# 335      0           1                  [Emphasizing Apperciation1]
# 342      0           1                         [Explicit Gratitude]
# 344      0           1  [Explicit Gratitude, Explicit Appreciation]
# 345      0           1                      [Explicit Appreciation]
# 354      0           1                         [Explicit Gratitude]
# 475      0           1                  [Emphasizing Apperciation1]
# 507      0           1                         [Explicit Gratitude]
# 612      0           1                         [Explicit Gratitude]
#
#             matching sequences
# 24                          []
# 30                 [Thank you]
# 39               [kind of you]
# 45                          []
# 68                [thanks for]
# 273                [thank you]
# 277                [Thank you]
# 279                [Thank you]
# 311                 [Thanks a]
# 313                 [Thanks a]
# 314                 [thanks a]
# 319    [Thanks USER, thanks a]
# 323                 [Thanks a]
# 335      [I really appreciate]
# 342                [Thank you]
# 344  [Thank you, I appreciate]
# 345             [I appreciate]
# 354                [Thank you]
# 475            [I really like]
# 507              [Thanks USER]
# 612               [Thanks for]

# %% [markdown]
# ## Check the false negatives:

# %%
print(len(data[(data['label']==1) & (data['prediction']==0)]))
data[(data['label']==1) & (data['prediction']==0)]
# Out:
# 22
#                                                                                                                                                                                                                                                                                      text  \
# 2                                                                                                                   USER Appreciate it. We love USER and only want to see her succeed in the future... so appreciate you letting me be your (somewhat worried) canary in the coal mine ;)
# 25                         USER wanted to give a shoutout to Jeremy at the Chipotle on 121 4th Street 135 in San Francisco. I ordered ahead and it wasn't ready but Jeremy jumped right in to make sure 1 i got my food and 2 I made my train. please recognize him! &amp; let me know :)
# 26                                                                                                                                                                             Made my day finding out USER have vegan Belgium Buns !! Really hope they expand more with vegan goodies :D
# 29                                                                                                                                                                                                                                                                    USER Made my day :D
# 32                                                                                                                                                                                            USER USER Ah, my bad! Anyway, a very kind and resourceful man to contact me immediately! :)
# 42   USER Wow! Hi. I didn’t expect a response but thankful for it. AMZL delivery. It Was originally to arrive yesterday. Then postponed to today. The amazon tracker said it was still out for delivery and would arrive by 8pm. At 11:30pm it still showed the pkg was out for delivery.
# 53                                                                                                                                                                                              USER So punny;) I ❤️ you, Southwest. Thankful for you today especially!!! BestAirlineEver
# 55                                                                                                                          USER That's very kind but I'm 21 hours into travel from Abu Dhabi right now. So very tired and cranky. I'm sure we'll be chatting again around 3pm :). Thanks
# 56                                                                                                                                                                              USER That was a game I will NEVER forget! As a lifelong Cubs fan, it was worth the wait! :) *TreBrewbaker
# 59                                                                                                                                                                                                                                                        USER You’re the best! Cheers :)
# 64                                                                                                                                                           USER my wife is 38 wks pregnant and was v grateful. Can you please give him a special Xmas bonus? ThanksDharmesh :-) ... 2/2
# 70                                                                                                                                                                                                                Thankful for all the updates we’ve gotten for our 12:30 flight USER 😬😳
# 72                                                                                                                                                                               USER 16:30 Birmingham to London Euston, the very kind staff at the shop are trying to sort something out
# 80                                                                                                                                       USER Sent a glowing review w/ the customer service inquiry. Especially grateful to your rep, James! He was great! Give him a high five for me :)
# 82                                                                                                                                                                                                                                                                USER You’re the best ♥️
# 85                                                                                                                                                                                    USER That's great! Thanks. I totally wanted to go outside to find my parcel ruined. Made my day :)
# 127                                                                                                                                                                                      USER Awww, IT'S CORRINE! Sure miss you :) Enjoy your vacay! xoxo &lt;3 This made my day :D -Suli
# 129                                                                                                                                                                                                   USER USER Awww bless, what treasure your Mum is, Emma! What did you have to eat? :)
# 155                                                                                                         USER Hi Tom, very good! Can't get fresher than that. I suppose I should be grateful he could have taken you to PC world and showed you a motherboard. ;-) Happy frying - Mark
# 174                                                                                                                                                                         USER We're humbled and appreciative. Please DM you Rapid Rewards number so we can follow-up with you. :) ^WB
# 330                                                                                                                                                                                                        USER Appreciate that. BTW: gate personnel are doing great and super helpful :)
# 347                                                                                  USER Of course, as someone who also works in customer success I️ can appreciate it’s the little things that go a long way and everyone on this flight is taking notice of the tone Greg is setting:)
#
#      label  prediction patterns matching sequences
# 2        1           0       []                 []
# 25       1           0       []                 []
# 26       1           0       []                 []
# 29       1           0       []                 []
# 32       1           0       []                 []
# 42       1           0       []                 []
# 53       1           0       []                 []
# 55       1           0       []                 []
# 56       1           0       []                 []
# 59       1           0       []                 []
# 64       1           0       []                 []
# 70       1           0       []                 []
# 72       1           0       []                 []
# 80       1           0       []                 []
# 82       1           0       []                 []
# 85       1           0       []                 []
# 127      1           0       []                 []
# 129      1           0       []                 []
# 155      1           0       []                 []
# 174      1           0       []                 []
# 330      1           0       []                 []
# 347      1           0       []                 []

# %% [markdown]
# ## Check the True Positives

# %%
print(len(data[(data['label']==1) & (data['prediction']==1)]))
data[(data['label']==1) & (data['prediction']==1)]
# Out:
# 210
#                                                                                                                                                                                                                   text  \
# 0                                                                                                                       USER Thank you for the reply! I appreciate the help :) the book is The Art Of Thor: Ragnarok:
# 1    USER Thank you for the reply Goldie. It's not just sainsburys ... I haven't seen them anywhere this year in supermarkets. Not even in the mixed nut bags :)) Appreciate your tweet though. Have a good weekend :)
# 3                                                                                                         USER Thanks so much. I meant to tweet not message, so I appreciate the quick reply!! Enjoy your weekend. :-)
# 4                                                              USER USER Dear USER USER USER thank you for taking action and getting back to me. Case has been solved thank you for your quick reply. Happy Weekend :)
# 5                                                                                                                USER Thank you for your help. I found it and it's currently downloading. Appreciate the assistance :)
# ..                                                                                                                                                                                                                 ...
# 339                                                                       USER USER USER USER Thanks! Appreciate the effort &amp; the update. It'd better be damn quick. I still got some binging of Catfish to do. :)
# 340                  USER No I get it, just thought I complain a little cause when I signed up for “limited ads” I thought maybe 3-4 every once in awhile not 2 long ads in a row. But I appreciate you responding! :)
# 343                                                                                USER That's a shame, thanks for looking though! That color combo is what I'm looking for though. Ah well ;) appreciate the attempt!
# 346                                                                                                    USER Thanks, but I've already checked and there is not a single store in my country, I appreciate the effort :D
# 348                                                                                                               USER Oh I didn't know that, I just set up my appointment. Thanks for the heads up. Appreciate it. :)
#
#      label  prediction                                     patterns  \
# 0        1           1  [Explicit Gratitude, Explicit Appreciation]
# 1        1           1                         [Explicit Gratitude]
# 3        1           1  [Explicit Gratitude, Explicit Appreciation]
# 4        1           1     [Explicit Gratitude, Explicit Gratitude]
# 5        1           1                         [Explicit Gratitude]
# ..     ...         ...                                          ...
# 339      1           1                         [Explicit Gratitude]
# 340      1           1                      [Explicit Appreciation]
# 343      1           1                         [Explicit Gratitude]
# 346      1           1  [Explicit Gratitude, Explicit Appreciation]
# 348      1           1                         [Explicit Gratitude]
#
#             matching sequences
# 0    [Thank you, I appreciate]
# 1                  [Thank you]
# 3    [Thanks so, I appreciate]
# 4       [thank you, thank you]
# 5                  [Thank you]
# ..                         ...
# 339                  [Thanks!]
# 340             [I appreciate]
# 343               [thanks for]
# 346    [Thanks,, I appreciate]
# 348               [Thanks for]
#
# [210 rows x 5 columns]

# %% [markdown]
# ## Check the True Negatives

# %%
print(len(data[(data['label']==0) & (data['prediction']==0)]))
data[(data['label']==0) & (data['prediction']==0)]
# Out:
# 277
#                                                                                                                                                                                                                                                                             text  \
# 23                                                                                                                                                                             USER I am having trouble printing on envelopes: printer does not recognize paper size hpsa hpprnt
# 36                                                                                                                                                    USER please recognize flight attendant COCO 4 buying me a drink when my voucher had expired! Orlando -&gt; Denver flight!
# 46   Tried to contact Spotify multiple times about the issue I'm having, to no avail. I keep getting "Error Code: 3" when I try to log in with my Facebook account, and it is saying it doesn't recognize my account when I have definitely signed up before. USER Can you help?
# 48                                                                                                                                                                                           USER after i click "nashville" inside the treasure truck menu it just sits here :)
# 60                                                                                                                                                      we said we weren’t gonna go black friday shopping but here we are standing in walmart @ 2 am :) thankful futurehubby 💚💍
# ..                                                                                                                                                                                                                                                                           ...
# 607                                                                                                                                                                                                                 USER 😱😱😱 DM us Becca - we need to get to the bottom of this!
# 608                                                                                                                                                                      USER We'd hate to see you go! We understand the frustration and will share your feedback with our team.
# 609                                                                                                                                         USER We would be too! We're so sorry to hear about the trouble you've been having, Tim. What device are you on? Running into errors?
# 610                                                                                                                  USER Terribly sorry for the agitation regarding your husband's account, Ailsa! What information were we able to provide when you contacted us about it? ^JZ
# 611                                                                                                                USER The 17:36 was cancelled due to a fault and 17:49 because of a broken down train earlier. Apologies for this and for any problems they have caused. Lewis
#
#      label  prediction patterns matching sequences
# 23       0           0       []                 []
# 36       0           0       []                 []
# 46       0           0       []                 []
# 48       0           0       []                 []
# 60       0           0       []                 []
# ..     ...         ...      ...                ...
# 607      0           0       []                 []
# 608      0           0       []                 []
# 609      0           0       []                 []
# 610      0           0       []                 []
# 611      0           0       []                 []
#
# [277 rows x 5 columns]
